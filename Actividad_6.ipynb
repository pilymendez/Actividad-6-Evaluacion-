# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os 
import pily as pl

# %% [markdown]
# **FUNCIÓN 1**

# %% [markdown]
# **Comprobar que la función solo funciona con .csv y .xlsx**

# %%
no = pl.cargar_dataset ('001.json')
no
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 no = pl.cargar_dataset ('001.json')
#       2 no
#
# File ~/Desktop/Profe Alfredo /7_examen/pily.py:13, in cargar_dataset(archivo)
#      11     return(df)
#      12 else:
# ---> 13         raise ValueError(f"Este formato no está soportado para esta función: {extension}")
#
# ValueError: Este formato no está soportado para esta función: .json

# %% [markdown]
# **Cargar el archivo de mi país**

# %%
# con el archivo pily.py
df = pl.cargar_dataset ('Francia.csv')
df
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %% [markdown]
# **FUNCIÓN 2**

# %%
#Sustituir nulos con mean, constante y string, siendo columnas pares, impares y no numéricas
df1 = pl.sustitucion_nulos(df)
df1
# Out:
#         host_id  host_listings_count   latitude  accommodates  bedrooms  \
# 0        269557                  1.0  45.763140             5       3.0
# 1        411285                  1.0  45.768420             4       1.0
# 2        660135                  1.0  45.759300             2       1.0
# 3        670404                  1.0  45.768845             2       1.0
# 4        832917                  5.0  45.766950             6       3.0
# ...         ...                  ...        ...           ...       ...
# 9886  651608878                 27.0  45.747560             5       2.0
# 9887  651608878                 27.0  45.757020             6       2.0
# 9888  666633599                  1.0  45.737954             2       1.0
# 9889   12466813                  1.0  45.744800             4       2.0
# 9890  417340177                 20.0  45.766985             2       1.0
#
#       price  maximum_nights  maximum_minimum_nights  maximum_maximum_nights  \
# ...

# %% [markdown]
# **FUNCIÓN 3**

# %%
#Identificar valores nulos
nulos = pl.valores_nulos(df1)
nulos
# Out:
# ('Valores nulos por columna',
#  host_id                                          0
#  host_listings_count                              0
#  latitude                                         0
#  accommodates                                     0
#  bedrooms                                         0
#  price                                            0
#  maximum_nights                                   0
#  maximum_minimum_nights                           0
#  maximum_maximum_nights                           0
#  maximum_nights_avg_ntm                           0
#  availability_60                                  0
#  availability_365                                 0
#  number_of_reviews_ltm                            0
#  review_scores_rating                             0
#  review_scores_checkin                            0
#  calculated_host_listings_count                   0
#  calculated_host_listings_count_entire_homes.1    0
# ...

# %% [markdown]
# **FUNCIÓN 4**

# %%
#Sustituir valores atípicos con rango intercuartílico
atipicos = pl.rango_iqr(df1)
atipicos
# Out:
# ('Limite superior permitido:',
#  host_id                                          5.230398e+08
#  host_listings_count                              3.500000e+00
#  latitude                                         4.579644e+01
#  accommodates                                     7.000000e+00
#  bedrooms                                         3.500000e+00
#  price                                            1.620000e+02
#  maximum_nights                                   2.722500e+03
#  maximum_minimum_nights                           7.200000e+01
#  maximum_maximum_nights                           2.452500e+03
#  maximum_nights_avg_ntm                           2.634525e+03
#  availability_60                                  1.050000e+02
#  availability_365                                 5.800000e+02
#  number_of_reviews_ltm                            2.750000e+01
#  review_scores_rating                             5.370000e+00
# ...

# %%
csv = df1.to_csv('Actividad_6_Evaluacion.csv')
